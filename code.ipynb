# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(pd.read_csv('Calls_for_Service_2015_20241226.csv'))

# %%
df.head()
# Out:
#   NOPD_Item Type_             TypeText Priority InitialType  \
# 0  A0000915    63              PROWLER       2C          63
# 1  A0000915    63              PROWLER       2C          63
# 2  A0001015    94  DISCHARGING FIREARM       2B          94
# 3  A0001115    94  DISCHARGING FIREARM       1A          94
# 4  A0001215    94  DISCHARGING FIREARM       1A          94
#
#        InitialTypeText InitialPriority     MapX    MapY  \
# 0              PROWLER              2C  3691999  525715
# 1              PROWLER              2C  3691999  525715
# 2  DISCHARGING FIREARM              2B  3668626  532154
# 3  DISCHARGING FIREARM              2B  3668441  538345
# 4  DISCHARGING FIREARM              2B  3684578  550848
#
#                TimeCreate  ...              TimeArrive  \
# 0  01/01/2015 12:03:26 AM  ...  01/01/2015 12:13:46 AM
# 1  01/01/2015 12:03:26 AM  ...  01/01/2015 12:13:46 AM
# 2  01/01/2015 12:03:43 AM  ...  01/01/2015 12:09:18 AM
# ...

# %%
duplicate_rows = df[df.duplicated()]
len(duplicate_rows)
# Out:
# 1

# %%
df.describe()
# Out:
#                MapX          MapY            Zip  PoliceDistrict
# count  4.327330e+05  4.327330e+05  424461.000000   432733.000000
# mean   4.700320e+06  6.270966e+05   70120.818659        4.538355
# std    5.777069e+06  5.108789e+05       5.856911        2.403991
# min    0.000000e+00  0.000000e+00   70112.000000        0.000000
# 25%    3.673916e+06  5.291740e+05   70116.000000        3.000000
# 50%    3.681672e+06  5.351340e+05   70119.000000        5.000000
# 75%    3.694194e+06  5.473520e+05   70126.000000        7.000000
# max    3.736900e+07  3.513814e+06   70148.000000        8.000000
